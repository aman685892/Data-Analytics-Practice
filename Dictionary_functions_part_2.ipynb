# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Analytics-Practice/blob/main/Dictionary_functions_part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Student={"name":"aman","age":21,"marks":56}
x=Student.setdefault("roll",67)
print(x)
print(Student)
# Out:
# 67
# {'name': 'aman', 'age': 21, 'marks': 56, 'roll': 67}
