# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Analytics-Practice/blob/main/String_functions_part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a="hello"
b="Hello123"
c="123456"
d="HELLO"
e=""
f="Hello 123@"
g="1.234"
h="Aman Is Fire Person"

# %%
print(a.isalnum())
# Out:
# True

# %%
print(b.isalnum())
# Out:
# True

# %%
print(c.isalnum())
# Out:
# True

# %%
print(d.isalnum())
# Out:
# True

# %%
print(e.isalnum())
# Out:
# False

# %%
print(f.isalnum())
# Out:
# False

# %%
print(g.isalnum())
# Out:
# False

# %%
# isalpha returns true if all characters in the string are in the alphabets
print(a.isalpha())
# Out:
# True

# %%
print(e.isalpha())
# Out:
# False

# %%
print(c.isalpha())
# Out:
# False

# %%
# isdecimal returns true if all characters  in the string are decimals
print(a.isdecimal())
# Out:
# False

# %%
print(c.isdecimal())
# Out:
# True

# %%
print(g.isdecimal())
# Out:
# False

# %%
# isdigit returns true if all characters in the string are digits
print(a.isdigit())
# Out:
# False

# %%
print(c.isdigit())
# Out:
# True

# %%
print(b.isdigit())
# Out:
# False

# %%
# isnumeric returns true if all characters in the string are numeric
print(a.isnumeric())
# Out:
# False

# %%
print(c.isnumeric())
# Out:
# True

# %%
# islower checks if the string is lowercase or not
print(a.islower())
# Out:
# True

# %%
print(b.islower())
# Out:
# False

# %%
print(c.islower())
# Out:
# False

# %%
print(d.islower())
# Out:
# False

# %%
# isupper returns true if all characters in the string is upper case
print(a.isupper())
# Out:
# False

# %%
print(b.isupper())
# Out:
# False

# %%
print(d.isupper())
# Out:
# True

# %%
# isspace returns true if all characters in the string are whitespace
print(e.isspace())
# Out:
# False

# %%
print(f.isspace())
# Out:
# False

# %%
# istitle returns true if the string follows the rules of the title
print(h.istitle())
# Out:
# True
