# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Analytics-Practice/blob/main/Set_functions_part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x={"Ironman","Captain America","Hulk"}
x.add("Spiderman")
print(x)
# Out:
# {'Ironman', 'Spiderman', 'Captain America', 'Hulk'}

# %%
#x.pop()
# print(x)

# %%
x.remove("Hulk") # to remove particaular from set
print(x)
# Out:
# {'Ironman', 'Spiderman', 'Captain America'}

# %%
x.discard("spiderman")
x
# Out:
# {'Captain America', 'Ironman', 'Spiderman'}

# %%
b=x.copy()
print(b)
# Out:
# {'Ironman', 'Spiderman', 'Captain America'}
