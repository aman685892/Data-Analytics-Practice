# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Analytics-Practice/blob/main/Problem_solving_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a= "Why fit in, when you are Born to stand out!"

# %% [markdown]
# **Write a program to find out Length of the following string**

# %%
b=len(a)
print("The length of the given string is:",b)
# Out:
# The length of the given string is: 43

# %% [markdown]
# **Write a program to check how many times 'o' is occuring**

# %%
print(a.count('o'))
# Out:
# 4

# %% [markdown]
# **Write a program to convert whole string into lower and uppercase**

# %%
x=a.lower()
print(x)
# Out:
# why fit in, when you are born to stand out!

# %%
y=a.upper()
print(y)
# Out:
# WHY FIT IN, WHEN YOU ARE BORN TO STAND OUT!

# %% [markdown]
# **Write a program to convert following string into a title**

# %%
z=a.title()
print(z)
# Out:
# Why Fit In, When You Are Born To Stand Out!

# %% [markdown]
# **Write a program to find an index number of "fit in"**

# %%
print(a.find("fit in"))
# Out:
# 4
