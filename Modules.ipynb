# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Analytics-Practice/blob/main/Modules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Haan 😄 ye confusion datetime.datetime.now() me system time ke hisaab se hoti hai —
# matlab ye tumhare computer ke clock ka time print karta hai, real local time nahi agar system ka time galat set hai.
#
# 👉 Isliye agar tumhare PC/laptop ka system time 02:08 dikhata hai, to datetime.now() bhi wahi dikhayega.
# Lekin tumhara actual local time (India) 07:39 AM hai — to difference ka reason hai system time ya timezone.**

# %%
# inbuilt-modules in python
import datetime
x=datetime.datetime.now()
print(x)
# Out:
# 2025-11-11 02:52:26.494995

# %%
y=datetime.datetime(2002,6,2)
print(y)
# Out:
# 2002-06-02 00:00:00

# %%
y.strftime("%a")
# Out:
# 'Sun'

# %%
y.strftime("%A")
# Out:
# 'Sunday'

# %%
y.strftime("%B")
# Out:
# 'June'

# %%
y.strftime("%m")
# Out:
# '06'

# %%
## random modules in python
import random
z=random.randint(1,100)
print(z

      )
# Out:
# 13

# %%
import random
list=["aman","rahul","kumar"]
c=random.choice(list)
print(c)
# Out:
# kumar

# %%
# math modules
import math
w=max(23,56,12)
print(w)
# Out:
# 56

# %%
k=min(12,34,67)
print(k)
# Out:
# 12

# %%
h=pow(2,10)
print(h)
# Out:
# 1024

# %%
b=math.sqrt(64)
print(b)
# Out:
# 8.0

# %%
c=abs(-12) ## to find absolute value ie to make it positive
print(c)
# Out:
# 12

# %%
r=math.floor(5.6)
print(r)
# Out:
# 5

# %%
s=math.ceil(6.9)
print(s)
# Out:
# 7

# %%
# %%writefile module01.py
def add(x,y):
  return(x+y)


employee={"name":"aman","age":21,"gender":"male"}
# Out:
# Overwriting module01.py

# %%
import importlib
import module01
importlib.reload(module01)
print(module01.add(12,23))
print(module01.employee["name"])
# Out:
# 35
# aman
