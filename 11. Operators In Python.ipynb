# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Analytics-Practice/blob/main/11.%20Operators%20In%20Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Arithmetic operation

a=10
b=5
add_result=a+b
sub_result=a-b
mul_result=a*b
div_result=a/b
mod_result=a%b
floor_div_result=a//b
exp_result=a**b
print(add_result)
print(sub_result)
print(mul_result)
print(div_result)
print(mod_result)
print(floor_div_result)
print(exp_result)
# Out:
# 15
# 5
# 50
# 2.0
# 0
# 2
# 100000

# %%
str1="aman"
str2="aman"
str1==str2
# Out:
# True

# %%
str1!=str2 ## != operator
# Out:
# False

# %%
## comparison operators
a=78
b=67
print(a>b)
print(a<b)
# Out:
# True
# False

# %%
## Logical oprator ,and,or,not
X=True
Y=True
result=X and Y
print(result)
# Out:
# True

# %%
Z=X or Y
print(Z)
# Out:
# True

# %%
m=True
n=False
conclusion=m or n
print(conclusion)
# Out:
# True

# %%
p=False
q=False
done=p or q
print(done)
# Out:
# False

# %%
## Logical operators
c=True
not c
# Out:
# False

# %%
s=False
not s
# Out:
# True
