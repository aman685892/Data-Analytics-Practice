# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Analytics-Practice/blob/main/13_Conditional_Statements_(if%2C_elif%2C_else).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age=22
if age>=18:
  print("You are eligible to vote")
else:
  print("You cant vote")
# Out:
# You are eligible to vote

# %%
num=int(input("Enter the number"))
if num>=0:
  print(" number is positive")
  if num%2==0:
   print("number is even")
  else:
    print("number is odd")
else:
  print("number is negative")
# Out:
# Enter the number56
#  number is positive
# number is even
