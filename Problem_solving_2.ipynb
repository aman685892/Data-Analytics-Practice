# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Analytics-Practice/blob/main/Problem_solving_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# write a program to check if a number is positive
num=int(input("Enter the number:"))
if num>0:
  print("Number is positive")
else:
  print("Number is negative")
# Out:
# Enter the number:9
# Number is positive

# %%
# write a program to check whether a number is odd or even
Number=int(input("Enter the number:"))
if Number%2==0:
  print("Number is even")
else:
  print("Number is odd")
# Out:
# Enter the number:79
# Number is odd

# %%
# write a program to create area calculator
print("****AREA CALCULATOR***")
print("""  press 1 to get area of the square
press 2 to get area of the rectangle
press 3 to get area of the circle
press 4 to get area of the triangle""")

choice=int(input("Enter a choice between 1-4:"))
if choice==1:
  side=float(input("Enter the side of the square:"))
  area=side**2
  print("The area of the square is:",area)
elif choice==2:
  length=float(input("Enter the length of the rectangle:"))
  width=float(input("Enter  the width of the rectangle"))
  area=length* width
  print("Area of the rectangle is:",area)
elif choice==3:
  radius=float(input("Enter the radius of the circle:"))
  area=3.14*(radius**2)
  print("Area of the circle is:",area)
elif choice==4:
  base=float(input("Enter the base of the traingle:"))
  height=float(input("Enter the height of the triangle "))
  area= 0.5* base*height
  print("Area of the triangle is:",area)
else:
  print("Invalid input")
# Out:
# ****AREA CALCULATOR***
#   press 1 to get area of the square
# press 2 to get area of the rectangle
# press 3 to get area of the circle
# press 4 to get area of the triangle
# Enter a choice between 1-4:4
# Enter the base of the traingle:4
# Enter the height of the triangle 5
# Area of the triangle is: 10.0

# %%
# write a program to check wheteher a passed letter is a vowel or not
letter=input("Enter the letter:")
if (letter in "aeiou") or (letter in "AEIOU"):
  print(" it is vowel")
else:
  print("Not vowel at all")
# Out:
# Enter the letter:e
#  it is vowel

# %%
# write a program to check if a number is a single digit number,or 2 digit ... upto 5 digits
num=int(input('Enter the number:'))
if num>=0 and num<=9:
  print("It is a single digit number:")
elif num>=10 and num<=99:
  print("It is double digit number:")
elif num>=100 and num<=999:
  print("It is triple digit number:")
elif num>1000 and num<=9999:
  print("It is four digit number:")
elif num>10000 and num<=99999:
    print("It is five digit number")
else:
  print("invalid input")
# Out:
# Enter the number:79
# It is double digit number:
