# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Analytics-Practice/blob/main/Dictionary_functions_part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Student={"name":"aman","age":21,"marks":45}
x=Student.get("age")
print(x)
# Out:
# 21

# %%
y=Student.get("name")
print(y)
# Out:
# aman

# %%
# item
z=Student.items()
print(z)
# Out:
# dict_items([('name', 'aman'), ('age', 21), ('marks', 45)])

# %%
# keys
print(Student.keys())
# Out:
# dict_keys(['name', 'age', 'marks'])

# %%
# values
print(Student.values())
# Out:
# dict_values(['aman', 21, 45])

# %%
# copy()
d=Student.copy()
print(d)
# Out:
# {'name': 'aman', 'age': 21, 'marks': 45}
