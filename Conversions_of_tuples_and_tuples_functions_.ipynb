# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Analytics-Practice/blob/main/Conversions_of_tuples_and_tuples_functions_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=("vivo","nokia","samsung","vodafone")
print(  "Before conversion:",type(a))
a=list(a)
print( "After conversion:",type(a))
print(a)
# Out:
# Before conversion: <class 'tuple'>
# After conversion: <class 'list'>
# ['vivo', 'nokia', 'samsung', 'vodafone']

# %%
a.append("apple")
print(a)
# Out:
# ['vivo', 'nokia', 'samsung', 'vodafone', 'apple']

# %%
a=tuple(a)
print(a)
# Out:
# ('vivo', 'nokia', 'samsung', 'vodafone', 'apple')

# %%
b=("aman","kumar","raj","karan","pandav","karan")

# %%
b.count("karan")
# Out:
# 2

# %%
print("Th index of the given string is : ",b.index("karan"))
# Out:
# Th index of the given string is :  3
