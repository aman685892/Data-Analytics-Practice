# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Analytics-Practice/blob/main/Problem_solving_part_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A=["aman","raju","amit","pawan"]
# write a program to swap first and fourth element
A[0],A[3]=A[3],A[0]
print(A)
# Out:
# ['pawan', 'raju', 'amit', 'aman']

# %%
# write a program to add a new value at second position
A.insert(1,"rahul")
print(A)
# Out:
# ['pawan', 'rahul', 'raju', 'amit', 'aman']

# %%
# write a program to delete a value from third position
A.pop(2)
print(A)
# Out:
# ['pawan', 'rahul', 'amit', 'aman']

# %%
B=[13,7,12,10]
# write a program to multiply all the numbers in the list
mul=1
for i in (B):
  mul*=i

print(mul)
# Out:
# 10920

# %%
# write a program to get the largest number from the lists
B.sort()
print(B)
# Out:
# [7, 10, 12, 13]

# %%
print("The largest number of the lists is:",B[-1] )
# Out:
# The largest number of the lists is: 13

# %%
print("The smallest value in the given list is:",B[0])
# Out:
# The smallest value in the given list is: 7
