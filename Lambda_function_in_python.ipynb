# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Analytics-Practice/blob/main/Lambda_function_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=lambda b:b*5 ## lambda b: b * 5 defines an anonymous function that takes one argument b and returns b * 5
print(a(7))
# Out:
# 35

# %%
x=lambda u,v,w:(u+v)*w
print(x(2,4,5))
# Out:
# 30
