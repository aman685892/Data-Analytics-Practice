# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Analytics-Practice/blob/main/operators_and_operands.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(3+6) // arithmetic addition
# Out:
# 9

# %%
print(7-8) // arithmetic subtraction
# Out:
# -1

# %%
print(2**10) // exponentiation
# Out:
# 1024

# %%
print(7//6)// floor division
# Out:
# 1

# %%
print(8%3)// modulus opearators
# Out:
# 2

# %% [markdown]
# **Comparison operators**

# %%
print(6>7)
# Out:
# False

# %%
print(7==7)
# Out:
# True

# %%
print(6<8)
# Out:
# True

# %%
print(8!=7)
# Out:
# True

# %%
print(6==6)
# Out:
# True

# %%
print(7>=7)
# Out:
# True

# %% [markdown]
# **Logical operators**

# %%
print(5>8 and 7<9)
# Out:
# False

# %%
print(7>6 and 7>5)
# Out:
# True

# %%
print(7<9 or 7>7)
# Out:
# True

# %%
print(not(7<9 or  7>7))
# Out:
# False

# %% [markdown]
# **Assignment oprators**

# %%
score=0
score+=7
print(score)
# Out:
# 7

# %%
x=8
x*=7
print(x)
# Out:
# 56

# %%
y=8
y-=6
print(y)
# Out:
# 2

# %% [markdown]
# **identity operators are used to compare whether two objects refer to the same memory location**

# %%
a=[1,2,3]
b=a
c=[1,2,3]
print(a is b)
# Out:
# True

# %%
print(a is not c)
# Out:
# True

# %%
print(b is c)
# Out:
# False

# %%
a=89
b=89
print(a is b)
# Out:
# True

# %% [markdown]
# **Bitwise opeartors**

# %%
print(bin(89)) // bin() is a builtin function in python to calculate binary of a given number
# Out:
# 0b1011001

# %%
a=19
b=8
print(a & b)
# Out:
# 0

# %%
a=10
b=8
print(a|b)
# Out:
# 10

# %% [markdown]
# **Bitwise xor opearations**

# %%
a=10
b=8
# same retorn 0 otherwise 1
print(a^b)
# Out:
# 2

# %%
print(10>>2) # left shift by 2
# Out:
# 2

# %%
print(10>>1)
# Out:
# 5

# %%
print(10<<1) # right shift by 1
# Out:
# 20

# %%
print(10<<2)
# Out:
# 40

# %% [markdown]
# **Membership operators**

# %%
a="aman"
print("a" in a)
# Out:
# True

# %%
print("p" not in a)
# Out:
# True

# %%
print("k" in a)
# Out:
# False
