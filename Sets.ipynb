# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Analytics-Practice/blob/main/Sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x={"Ironman","Hulk","Captain America","Spiderman"}
print(x)
print(type(x))
# Out:
# {'Ironman', 'Spiderman', 'Captain America', 'Hulk'}
# <class 'set'>

# %%
for i in x:
  print(i) # sets are mutable and unordered and unique
# Out:
# Ironman
# Spiderman
# Captain America
# Hulk
