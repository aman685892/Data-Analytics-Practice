# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Analytics-Practice/blob/main/Strings_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s="Hello"
print(s[1]) ## indexing in string
print(s[1:4]) ## slicing in string
# Out:
# e
# ell

# %%
for ch in s:
  print(ch)
# Out:
# H
# e
# l
# l
# o

# %%
## important string functions
s="hello"
s.capitalize()
# Out:
# 'Hello'

# %%
string="hello world"
print(string.title())
# Out:
# Hello World

# %%
string.upper()
# Out:
# 'HELLO WORLD'

# %%
print(string)
# Out:
# hello world

# %%
s_tring="AMAN"
s_tring.lower()
# Out:
# 'aman'

# %%
x='aman'
x.endswith('an')
# Out:
# True

# %%
x.startswith('am')
# Out:
# True

# %%
print(x)
print(type(x))
# Out:
# aman
# <class 'str'>

# %%
x.index('n')
# Out:
# 3

# %%
fruit="banana"
fruit.count('a')
# Out:
# 3

# %%
fruit.zfill(10) ## zfill() adds zeros to make its length equal to final length 10
# Out:
# '0000banana'

# %%
fruit.center(10) ## adds equal space on both sides to make length 10
# Out:
# '  banana  '

# %%
" ".join(['a','m','a','n']) ##join() combines the list items and inserts the separator between them.
# Out:
# 'a m a n'
