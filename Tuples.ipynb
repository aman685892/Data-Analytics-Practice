# %% [markdown]
# <a href="https://colab.research.google.com/github/aman685892/Data-Analytics-Practice/blob/main/Tuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=("aman","rahul","rajkumar",1,3)
print(a)
# Out:
# ('aman', 'rahul', 'rajkumar', 1, 3)

# %%
print(type(a))
# Out:
# <class 'tuple'>

# %%
b="aman","emran","pankaj",1,56.8
print(b)
print(type(b))
# Out:
# ('aman', 'emran', 'pankaj', 1, 56.8)
# <class 'tuple'>

# %%
c="aman"
print(type(c))
# Out:
# <class 'str'>

# %%
d=("emran",c)
print(type(d))
# Out:
# <class 'tuple'>
